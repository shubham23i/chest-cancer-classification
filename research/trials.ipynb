# %%
import gdown

# %%
url="https://drive.google.com/drive/folders/1V5EomboE3aJGHjTr9pyrjdO3fWps5zNS?usp=sharing"

# %%
url.split("/")
# Out:
# ['https:',
#  '',
#  'drive.google.com',
#  'drive',
#  'folders',
#  '1V5EomboE3aJGHjTr9pyrjdO3fWps5zNS?usp=sharing']

# %%
file_id=url.split("/")[-1]
file_id=file_id.split("?")[0]
file_id
# Out:
# '1V5EomboE3aJGHjTr9pyrjdO3fWps5zNS'

# %%
prefix = "https://drive.google.com/uc?/export=download&id="

# %%
gdown.download_folder(
    url="https://drive.google.com/drive/folders/1V5EomboE3aJGHjTr9pyrjdO3fWps5zNS",
    quiet=False,
    resume=True
)
# Out:
# Retrieving folder contents
# Retrieving folder 1ZU6kqzK9wEpNumHMa-L5QdzVXULVdTqa test
# Retrieving folder 1SMjdgHIwl5DYiN4seDdhWarW1KDSSr6q adenocarcinoma
# Processing file 1Gv2DbczE1nrGk95Yeh88ochAMVdGG4j7 000108 (3).png
# Processing file 19KkJrHhRla4I5VoAguRZpFM5rW2Vpu5M 000109 (2).png
# Processing file 1l9vmVGNH4GCMldLbwLsh4yVmnkTQcYMY 000109 (4).png
# Processing file 1ZM9hc3YVtyAA_Vo2i_rBQYfHUMyz4HM1 000109 (5).png
# Processing file 1aR3H3g7EWDwGPs1VuRYV2Aje1MCZGjvS 000112 (2).png
# Processing file 1mgy6A6z4pzH_ab8p_BUtpQ5FdB75Qir6 000113 (7).png
# Processing file 1cUqOJeJUsDM2QBACPn7Q1qIWEoAo-ObH 000114 (5).png
# Processing file 1lQiTbQbgnFDmWlx5rUi_v0ifr7JdKPvP 000114.png
# Processing file 1oximnrZVIrR-ue_-01IzLZfp2yDIv2-f 000115 (4).png
# Processing file 1XmNimf6eQNuokLVIq5H2ZHhf2QKC-j-g 000115 (8).png
# Processing file 1tbUWIFKWyd7KmkYo6WxN8QOf0UR1Cn1h 000115.png
# Processing file 13CkJXv7y-fYLAPKd5H_eTMYmFV8-tHhE 000116 (5).png
# ...
